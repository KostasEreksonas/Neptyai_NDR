# %%
# !./download_datasets.sh
# Out:
# Datasets already downloaded

# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import glob
import os

# %% [markdown]
# ## General Info

# %%
# !ls datasets.uwf.edu/data/UWF-ZeekData22/csv
# Out:
# index.html
# part-00000-0af89d10-df53-44fd-b124-a8a496fd5023-c000.csv
# part-00000-15e3dd03-ea76-429e-a52a-ce96a90517f9-c000.csv
# part-00000-318611a1-7cdc-4dd0-9348-c6368917fd0c-c000.csv
# part-00000-5b4f5c3f-e8a9-4020-8fa1-e8985f7c27f3-c000.csv
# part-00000-95e0a460-e7c5-4b35-8367-c2e6fbbcf9e1-c000.csv

# %%
# Source - https://stackoverflow.com/a/21232849
# Posted by Gaurav Singh, modified by community. See post 'Timeline' for change history
# Retrieved 2026-02-05, License - CC BY-SA 4.0
path = 'datasets.uwf.edu/data/UWF-ZeekData22/csv'

all_files = glob.glob(os.path.join(path, "*.csv"))

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# %%
df.head()
# Out:
#    resp_pkts service  orig_ip_bytes  local_resp  missed_bytes protocol  \
# 0          2     dns            186       False             0      udp
# 1          2     dns            186       False             0      udp
# 2          2     dns            186       False             0      udp
# 3          2     dns            186       False             0      udp
# 4          2     dns            186       False             0      udp
#
#    duration conn_state     dest_ip  orig_pkts  ... orig_bytes  local_orig  \
# 0  0.002242         SF  143.88.5.1          2  ...      130.0       False
# 1  0.002242         SF  143.88.5.1          2  ...      130.0       False
# 2  0.002242         SF  143.88.5.1          2  ...      130.0       False
# 3  0.002242         SF  143.88.5.1          2  ...      130.0       False
# 4  0.002242         SF  143.88.5.1          2  ...      130.0       False
#
#                    datetime  history  resp_bytes                 uid src_port  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2044734 entries, 0 to 2044733
# Data columns (total 23 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   resp_pkts             int64
#  1   service               str
#  2   orig_ip_bytes         int64
#  3   local_resp            bool
#  4   missed_bytes          int64
#  5   protocol              str
#  6   duration              float64
#  7   conn_state            str
#  8   dest_ip               str
#  9   orig_pkts             int64
#  10  community_id          str
#  11  resp_ip_bytes         int64
#  12  dest_port             int64
#  13  orig_bytes            float64
#  14  local_orig            bool
#  15  datetime              str
#  16  history               str
#  17  resp_bytes            float64
#  18  uid                   str
#  19  src_port              int64
#  20  ts                    float64
#  21  src_ip                str
#  22  mitre_attack_tactics  str
# ...

# %%
df.shape
# Out:
# (2044734, 23)

# %%
df.describe()
# Out:
#           resp_pkts  orig_ip_bytes  missed_bytes      duration     orig_pkts  \
# count  2.044734e+06   2.044734e+06     2044734.0  1.911026e+06  2.044734e+06
# mean   4.936769e-01   1.390265e+02           0.0  1.013891e+00  1.820737e+00
# std    8.687251e-01   1.078382e+02           0.0  4.039728e+00  1.070112e+00
# min    0.000000e+00   0.000000e+00           0.0  9.536743e-07  0.000000e+00
# 25%    0.000000e+00   1.340000e+02           0.0  1.406670e-05  2.000000e+00
# 50%    0.000000e+00   1.380000e+02           0.0  1.883507e-05  2.000000e+00
# 75%    1.000000e+00   1.580000e+02           0.0  1.578331e-04  2.000000e+00
# max    9.000000e+01   1.123100e+04           0.0  3.256383e+02  7.100000e+01
#
#        resp_ip_bytes     dest_port    orig_bytes    resp_bytes      src_port  \
# count   2.044734e+06  2.044734e+06  1.911026e+06  1.911026e+06  2.044734e+06
# mean    3.873640e+01  1.559832e+02  4.692287e+03  2.469625e+01  4.580034e+04
# ...

# %% [markdown]
# Check for null values

# %%
df.isna().any()
# Out:
# resp_pkts               False
# service                  True
# orig_ip_bytes           False
# local_resp              False
# missed_bytes            False
# protocol                False
# duration                 True
# conn_state              False
# dest_ip                 False
# orig_pkts               False
# community_id            False
# resp_ip_bytes           False
# dest_port               False
# orig_bytes               True
# local_orig              False
# datetime                False
# history                  True
# resp_bytes               True
# uid                     False
# src_port                False
# ts                      False
# src_ip                  False
# mitre_attack_tactics    False
# dtype: bool

# %%
df.isna().sum()
# Out:
# resp_pkts                    0
# service                  53389
# orig_ip_bytes                0
# local_resp                   0
# missed_bytes                 0
# protocol                     0
# duration                133708
# conn_state                   0
# dest_ip                      0
# orig_pkts                    0
# community_id                 0
# resp_ip_bytes                0
# dest_port                    0
# orig_bytes              133708
# local_orig                   0
# datetime                     0
# history                  18517
# resp_bytes              133708
# uid                          0
# src_port                     0
# ts                           0
# src_ip                       0
# mitre_attack_tactics         0
# dtype: int64

# %%
df['service']
# Out:
# 0          dns
# 1          dns
# 2          dns
# 3          dns
# 4          dns
#           ...
# 2044729    dns
# 2044730    dns
# 2044731    dns
# 2044732    dns
# 2044733    dns
# Name: service, Length: 2044734, dtype: str

# %%
df['service'].unique()
# Out:
# <StringArray>
# ['dns', 'dhcp', 'ntp', 'ssl']
# Length: 4, dtype: str

# %% [markdown]
# # Class distribution

# %%
df['mitre_attack_tactics'].unique()
# Out:
# <StringArray>
# ['Reconnaissance', 'none']
# Length: 2, dtype: str
